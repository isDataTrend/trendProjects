# %%
import pandas as pd
import numpy as np

# %%
songs = pd.read_csv('songs_normalize.csv')

# %%
songs.sample(8)
# Out:
#                       artist                               song duration_ms  \
# 46            Samantha Mumba                     Gotta Tell You      201946
# 1082            Jason Derulo                        Ridin' Solo      215746
# 560   Thirty Seconds To Mars                           The Kill      231533
# 711             Alex Gaudino  Destination Calabria - Radio Edit      223111
# 1529                   KALEO                     Way down We Go      219560
# 1280                   Train                           Drive By      195973
# 412                  Ashanti                  Only U - No Intro      186306
# 1067               Shontelle                         Impossible      226533
#
#      explicit  year  popularity  danceability  energy  key  loudness  mode  \
# 46      False  2018          43        729.00  632.00    0     -8.75     0
# 1082    False  2010          66        442.00    0.83    9     -4.02     1
# 560     False  2005          74        179.00  912.00    4  -3881.00     0
# 711     False  2007          73        627.00  954.00    2  -4804.00     1
# 1529    False  2015          63          0.59  578.00   10  -5798.00     0
# 1280    False  2012          77        765.00  837.00    1  -3113.00     0
# 412     False  2004          56        601.00  621.00    6  -5576.00     0
# 1067    False  2010          35        599.00  624.00    8  -3631.00     1
#
#       speechiness  acousticness instrumentalness  liveness  valence  \
# 46         0.0279     191.00000              0.0  166.0000    774.0
# 1082     146.0000     128.00000              0.0  129.0000    578.0
# 560        0.0791       0.00140         0.000294  582.0000    289.0
# 711        0.0425       0.00150         0.000814  292.0000    312.0
# 1529       0.0528     612.00000         0.000162    0.0837    264.0
# 1280      32.0000       0.00107         1.06e-05    0.0801    721.0
# 412        0.0434       0.03740         1.75e-06  188.0000    278.0
# 1067       0.0343     385.00000              0.0  125.0000    539.0
#
#           tempo              genre Unnamed: 18
# 46    109981.00                pop         NaN
# 1082   89338.00       hip hop, pop         NaN
# 560      182.99               rock         NaN
# 711   128016.00   Dance/Electronic         NaN
# 1529   81663.00    rock, classical         NaN
# 1280  122028.00                pop         NaN
# 412    94547.00  hip hop, pop, R&B         NaN
# 1067   90034.00           pop, R&B         NaN

# %%
songs.shape
# Out:
# (2000, 19)

# %% [markdown]
# #### Q1) Using groupby(), plot the number of songs that have been released each year. Please, use the kind='bar', xlabel=year and ylabel ='Count of songs' and the size of figure should be (12,8) ---- <font color='blue'> (15 points)</font>

# %%
byyear=songs.groupby(['year']).count().plot(kind = "bar", xlabel='year', ylabel ='Count of songs',figsize=(10,6))

# %% [markdown]
# #### Q2) Use groupby() to present how many songs does Rihanna have over years. <font color='blue'> (10 points)</font>

# %%
#byRihanna=songs[songs['artist']=='Rihanna']
byRihanna=songs.groupby(['artist'])
byRihanna.get_group('Rihanna')
# Out:
#        artist                        song duration_ms explicit  year  \
# 503   Rihanna               Pon de Replay      246960    False  2005
# 605   Rihanna                         SOS      238920    False  2006
# 648   Rihanna                  Unfaithful      226973    False  2006
# 701   Rihanna                    Umbrella      275986    False  2008
# 726   Rihanna           Shut Up And Drive      212280    False  2008
# 802   Rihanna                  Take A Bow      229413    False  2008
# 811   Rihanna                   Disturbia      238626    False  2008
# 819   Rihanna        Don't Stop The Music      267080    False  2008
# 935   Rihanna            Russian Roulette      227533     True  2009
# 1007  Rihanna    Only Girl (In The World)      235493    False  2010
# 1015  Rihanna                      Te Amo      208426     True  2009
# 1024  Rihanna                    Rude Boy      222920     True  2009
# 1042  Rihanna                        Hard      250600     True  2009
# 1052  Rihanna                    Man Down      267000     True  2010
# 1066  Rihanna             What's My Name?      263173    False  2010
# 1109  Rihanna                         S&M      243533    False  2010
# 1150  Rihanna               We Found Love      215226    False  2011
# 1158  Rihanna             What's My Name?      263173    False  2010
# 1200  Rihanna               We Found Love      215226    False  2011
# 1208  Rihanna         Where Have You Been      242680    False  2011
# 1230  Rihanna                    Diamonds      225146    False  2012
# 1396  Rihanna                        Stay      240706    False  2012
# 1539  Rihanna  Bitch Better Have My Money      219305     True  2015
# 1609  Rihanna                        Work      219320     True  2016
# 1636  Rihanna                   Needed Me      191600     True  2016
#
#       popularity  danceability  energy  key  loudness  mode  speechiness  \
# 503           77        779.00    0.64    7  -8415.00     1     159.0000
# 605           73        677.00  671.00    7  -4905.00     1       0.0361
# 648           70        588.00  391.00    0  -8607.00     0       0.0334
# 701           81        583.00  829.00    1  -4603.00     1     134.0000
# 726           69        735.00  826.00    1  -4902.00     1       0.0349
# 802           74        697.00  467.00    9  -7536.00     1       0.0715
# 811           76        707.00  813.00   11  -4515.00     0       0.0571
# 819           77        835.00  669.00    6  -5582.00     0       0.0643
# 935           64          0.48  486.00    6  -5754.00     0       0.0447
# 1007          73        789.00  716.00   11  -4241.00     0       0.0432
# 1015          67        567.00  707.00    8  -5455.00     0       0.0818
# 1024          74        563.00    0.75   11  -4496.00     1     127.0000
# 1042          55          0.31  746.00    1  -3599.00     1     111.0000
# 1052          68          0.47  904.00    0  -4024.00     0     177.0000
# 1066          66        692.00  786.00    2  -2959.00     1      69.0000
# 1109          73        767.00  682.00    1     -5.02     1      42.0000
# 1150          75        735.00  766.00    1  -4485.00     1       0.0383
# 1158          66        692.00  786.00    2  -2959.00     1      69.0000
# 1200          75        735.00  766.00    1  -4485.00     1       0.0383
# 1208          71        719.00  847.00    0     -6.34     0       0.0916
# 1230          75        564.00    0.71   11     -4.92     0       0.0461
# 1396          76        621.00    0.31    9 -10164.00     0       0.0283
# 1539          73        781.00  728.00    1  -4981.00     1       0.0621
# 1609          75        725.00  534.00   11  -6238.00     1       0.0946
# 1636          80        671.00  314.00    5  -8091.00     0     244.0000
#
#       acousticness instrumentalness  liveness  valence      tempo  \
# 503       0.000155          0.00077  101.0000   498.00   99019.00
# 605       4.000000         5.07e-05  413.0000   527.00  137046.00
# 648     839.000000              0.0  227.0000   349.00  144069.00
# 701       0.008640              0.0    0.0426   575.00  174028.00
# 726       0.001010              129  197.0000     0.74  132964.00
# 802     248.000000              0.0    0.0941   572.00   82082.00
# 811       0.086300              0.0  168.0000   722.00  124921.00
# 819       0.033600         6.92e-05    0.0535   542.00  122668.00
# 935      46.000000              0.0  107.0000   265.00   80051.00
# 1007    129.000000         1.07e-05   69.0000   611.00  125906.00
# 1015    541.000000         0.000176    0.1000   751.00  171917.00
# 1024    113.000000              0.0    0.0788   812.00  173906.00
# 1042      0.012100              0.0  649.0000   163.00  182032.00
# 1052      0.043600              0.0    0.0491   557.00  155788.00
# 1066      0.230000              0.0    0.0797   583.00  100025.00
# 1109      0.011300          0.00016  104.0000   833.00  127975.00
# 1150     25.000000          0.00138  108.0000     0.60  127985.00
# 1158      0.230000              0.0    0.0797   583.00  100025.00
# 1200     25.000000          0.00138  108.0000     0.60  127985.00
# 1208      0.002010           0.0204  223.0000   444.00  127963.00
# 1230      0.001250              0.0  109.0000   393.00   91972.00
# 1396    945.000000         6.12e-05  117.0000   125.00  111893.00
# 1539      0.050900         1.94e-06  257.0000   395.00     102.99
# 1609      0.075200              0.0    0.0919   558.00   91974.00
# 1636      0.110000              0.0    0.0825   296.00  110898.00
#
#                   genre Unnamed: 18
# 503   hip hop, pop, R&B         NaN
# 605   hip hop, pop, R&B         NaN
# 648   hip hop, pop, R&B         NaN
# 701   hip hop, pop, R&B         NaN
# 726   hip hop, pop, R&B         NaN
# 802   hip hop, pop, R&B         NaN
# 811   hip hop, pop, R&B         NaN
# 819   hip hop, pop, R&B         NaN
# 935   hip hop, pop, R&B         NaN
# 1007  hip hop, pop, R&B         NaN
# 1015  hip hop, pop, R&B         NaN
# 1024  hip hop, pop, R&B         NaN
# 1042  hip hop, pop, R&B         NaN
# 1052  hip hop, pop, R&B         NaN
# 1066  hip hop, pop, R&B         NaN
# 1109  hip hop, pop, R&B         NaN
# 1150  hip hop, pop, R&B         NaN
# 1158  hip hop, pop, R&B         NaN
# 1200  hip hop, pop, R&B         NaN
# 1208  hip hop, pop, R&B         NaN
# 1230  hip hop, pop, R&B         NaN
# 1396  hip hop, pop, R&B         NaN
# 1539  hip hop, pop, R&B         NaN
# 1609  hip hop, pop, R&B         NaN
# 1636  hip hop, pop, R&B         NaN

# %%
byRihanna.groupby(['year']).count()
# Out:
#       artist  song  duration_ms  explicit  popularity  danceability  energy  \
# year
# 2005       1     1            1         1           1             1       1
# 2006       2     2            2         2           2             2       2
# 2008       5     5            5         5           5             5       5
# 2009       4     4            4         4           4             4       4
# 2010       5     5            5         5           5             5       5
# 2011       3     3            3         3           3             3       3
# 2012       2     2            2         2           2             2       2
# 2015       1     1            1         1           1             1       1
# 2016       2     2            2         2           2             2       2
#
#       key  loudness  mode  speechiness  acousticness  instrumentalness  \
# year
# 2005    1         1     1            1             1                 1
# 2006    2         2     2            2             2                 2
# 2008    5         5     5            5             5                 5
# 2009    4         4     4            4             4                 4
# 2010    5         5     5            5             5                 5
# 2011    3         3     3            3             3                 3
# 2012    2         2     2            2             2                 2
# 2015    1         1     1            1             1                 1
# 2016    2         2     2            2             2                 2
#
#       liveness  valence  tempo  genre  Unnamed: 18
# year
# 2005         1        1      1      1            0
# 2006         2        2      2      2            0
# 2008         5        5      5      5            0
# 2009         4        4      4      4            0
# 2010         5        5      5      5            0
# 2011         3        3      3      3            0
# 2012         2        2      2      2            0
# 2015         1        1      1      1            0
# 2016         2        2      2      2            0

# %% [markdown]
# #### Q3) Use groupby() to sort the number of artists released pop(only!) songs in 2011. <font color='blue'> (10 points)</font>

# %%
#popOnly=songs[songs['genre']=='pop']
#popOnly_2011=popOnly[popOnly['year']=='2011']
#popOnly_2011
popOnly=songs.groupby(['genre', 'year'])
popOnly_2011=popOnly.get_group(('pop','2011'))
popOnly_2011
# Out:
#                artist                     song duration_ms explicit  year  \
# 10    Gigi D'Agostino         L'Amour Toujours      238759    False  2011
# 1096      Matt Cardle          When We Collide      226000    False  2011
# 1122   Britney Spears               I Wanna Go      210266    False  2011
# 1136   Britney Spears      Till the World Ends      237946    False  2011
# 1160    Avril Lavigne            What the Hell      220706    False  2011
# 1166        Lady Gaga            Born This Way      260253    False  2011
# 1187        Lady Gaga        The Edge Of Glory      320546    False  2011
# 1194  Christina Perri            Jar of Hearts      246587    False  2011
# 1198  Charlene Soraia     Wherever You Will Go      197577    False  2011
# 1199  Christina Perri         A Thousand Years      285120    False  2011
# 1295      Demi Lovato  Give Your Heart a Break      205346    False  2011
# 1298       Bruno Mars             It Will Rain      257720    False  2011
#
#       popularity  danceability  energy  key  loudness  mode  speechiness  \
# 10             1         617.0   728.0    7  -7932.00     1       0.0292
# 1096          46         443.0   683.0    2  -5521.00     1       0.0343
# 1122          66         696.0   546.0    5     -6.55     1       0.0414
# 1136          65         693.0   705.0    8  -5747.00     1       0.0665
# 1160          74         578.0   926.0    6  -3689.00     0       0.0548
# 1166          72         587.0   828.0   11  -5108.00     1     161.0000
# 1187          67         583.0   768.0    9  -6477.00     1      41.0000
# 1194          72         349.0   348.0    3  -6142.00     1       0.0316
# 1198          60         597.0   115.0    9  -9217.00     1       0.0334
# 1199          70         421.0   407.0   10  -7445.00     1       0.0267
# 1295          71         651.0   695.0    6  -3218.00     1       0.0487
# 1298          74         576.0   835.0    2  -6826.00     1       0.0486
#
#       acousticness instrumentalness  liveness   valence     tempo genre  \
# 10        0.032800           0.0482      0.36  808.0000  139066.0   pop
# 1096      0.019800         5.26e-06    313.00  447.0000   81986.0   pop
# 1122      0.003790          3.8e-06    332.00  787.0000  130002.0   pop
# 1136      0.022800              0.0    202.00    0.4500  131951.0   pop
# 1160      0.004720           0.0127      0.14  877.0000  149976.0   pop
# 1166      0.003270              0.0    331.00  494.0000  123907.0   pop
# 1187      0.000323           0.0162    109.00  357.0000  127952.0   pop
# 1194    726.000000              0.0      0.12    0.0886   74541.0   pop
# 1198      0.820000         0.000215    111.00  128.0000  111202.0   pop
# 1199    309.000000         0.000961      0.11  161.0000  139028.0   pop
# 1295      0.230000              0.0    144.00  569.0000  123008.0   pop
# 1298    337.000000              0.0     82.00  476.0000  150017.0   pop
#
#      Unnamed: 18
# 10           NaN
# 1096         NaN
# 1122         NaN
# 1136         NaN
# 1160         NaN
# 1166         NaN
# 1187         NaN
# 1194         NaN
# 1198         NaN
# 1199         NaN
# 1295         NaN
# 1298         NaN

# %%
popOnly_2011.groupby(['artist']).count()
# Out:
#                  song  duration_ms  explicit  year  popularity  danceability  \
# artist
# Avril Lavigne       1            1         1     1           1             1
# Britney Spears      2            2         2     2           2             2
# Bruno Mars          1            1         1     1           1             1
# Charlene Soraia     1            1         1     1           1             1
# Christina Perri     2            2         2     2           2             2
# Demi Lovato         1            1         1     1           1             1
# Gigi D'Agostino     1            1         1     1           1             1
# Lady Gaga           2            2         2     2           2             2
# Matt Cardle         1            1         1     1           1             1
#
#                  energy  key  loudness  mode  speechiness  acousticness  \
# artist
# Avril Lavigne         1    1         1     1            1             1
# Britney Spears        2    2         2     2            2             2
# Bruno Mars            1    1         1     1            1             1
# Charlene Soraia       1    1         1     1            1             1
# Christina Perri       2    2         2     2            2             2
# Demi Lovato           1    1         1     1            1             1
# Gigi D'Agostino       1    1         1     1            1             1
# Lady Gaga             2    2         2     2            2             2
# Matt Cardle           1    1         1     1            1             1
#
#                  instrumentalness  liveness  valence  tempo  genre  \
# artist
# Avril Lavigne                   1         1        1      1      1
# Britney Spears                  2         2        2      2      2
# Bruno Mars                      1         1        1      1      1
# Charlene Soraia                 1         1        1      1      1
# Christina Perri                 2         2        2      2      2
# Demi Lovato                     1         1        1      1      1
# Gigi D'Agostino                 1         1        1      1      1
# Lady Gaga                       2         2        2      2      2
# Matt Cardle                     1         1        1      1      1
#
#                  Unnamed: 18
# artist
# Avril Lavigne              0
# Britney Spears             0
# Bruno Mars                 0
# Charlene Soraia            0
# Christina Perri            0
# Demi Lovato                0
# Gigi D'Agostino            0
# Lady Gaga                  0
# Matt Cardle                0

# %% [markdown]
# #### Q5) List, in order by year, each of the genres in which Calvin Harris has released more than 1 songs. <font color='blue'> (15 points)</font>

# %%
CHarris=songs[songs['artist']=='Calvin Harris']
CHarris.sample(5)
# Out:
#              artist                                   song duration_ms  \
# 1429  Calvin Harris              Blame (feat. John Newman)      212960
# 1244  Calvin Harris             Feel So Close - Radio Edit      206413
# 1521  Calvin Harris                  How Deep Is Your Love      212640
# 1369  Calvin Harris  Thinking About You (feat. Ayah Marar)      247933
# 1954  Calvin Harris            Giant (with Rag'n'Bone Man)      229184
#
#      explicit  year  popularity  danceability  energy  key  loudness  mode  \
# 1429    False  2014          75         414.0   857.0    0   -4078.0     0
# 1244    False  2012          79         707.0   924.0    7   -2842.0     1
# 1521    False  2015          76         738.0   868.0   11   -4373.0     0
# 1369    False  2012          65         725.0   874.0    0   -3715.0     0
# 1954    False  2019          73         807.0   887.0    1   -4311.0     0
#
#       speechiness  acousticness instrumentalness  liveness  valence     tempo  \
# 1429       0.0808      0.028700          0.00574  343.0000    348.0  128024.0
# 1244      31.0000      0.000972          0.00703  204.0000    919.0  127937.0
# 1521       0.0731      0.039200          0.00169  388.0000    336.0  122003.0
# 1369       0.0396      0.002620         0.000412    0.0958    748.0  127985.0
# 1954       0.0361     16.000000         0.000503    0.0811    606.0  122015.0
#
#                                genre Unnamed: 18
# 1429  hip hop, pop, Dance/Electronic         NaN
# 1244  hip hop, pop, Dance/Electronic         NaN
# 1521  hip hop, pop, Dance/Electronic         NaN
# 1369  hip hop, pop, Dance/Electronic         NaN
# 1954  hip hop, pop, Dance/Electronic         NaN

# %%
CHgroup=CHarris.groupby(['year', 'genre'])
c=CHgroup.count()

c.loc[c['artist']>1]
# Out:
#                                      artist  song  duration_ms  explicit  \
# year genre
# 2012 hip hop, pop, Dance/Electronic       8     8            8         8
# 2014 hip hop, pop, Dance/Electronic       4     4            4         4
# 2016 hip hop, pop, Dance/Electronic       2     2            2         2
#
#                                      popularity  danceability  energy  key  \
# year genre
# 2012 hip hop, pop, Dance/Electronic           8             8       8    8
# 2014 hip hop, pop, Dance/Electronic           4             4       4    4
# 2016 hip hop, pop, Dance/Electronic           2             2       2    2
#
#                                      loudness  mode  speechiness  \
# year genre
# 2012 hip hop, pop, Dance/Electronic         8     8            8
# 2014 hip hop, pop, Dance/Electronic         4     4            4
# 2016 hip hop, pop, Dance/Electronic         2     2            2
#
#                                      acousticness  instrumentalness  liveness  \
# year genre
# 2012 hip hop, pop, Dance/Electronic             8                 8         8
# 2014 hip hop, pop, Dance/Electronic             4                 4         4
# 2016 hip hop, pop, Dance/Electronic             2                 2         2
#
#                                      valence  tempo  Unnamed: 18
# year genre
# 2012 hip hop, pop, Dance/Electronic        8      8            0
# 2014 hip hop, pop, Dance/Electronic        4      4            0
# 2016 hip hop, pop, Dance/Electronic        2      2            0

# %%
# Out:
# [-1]

# %% [markdown]
# #### Q6) <font color='blue'> TOTAL: (50 points)</font>
# * Define a new datafame which contains the popularity, danceability, energy, year, tempo, song.  <font color='blue'> (5 points)</font>
# * Use transform() to define a new column which represent percantage of popularity (pop%). <font color='blue'> (10 points)</font>
# * Set the index of dataframe as year assign new data frame as song_rearranged<font color='blue'> (10 points)</font>
# * Describe a new column as 'score' by considering mean of popularity, danceability, energy constants. <font color='blue'> (10 points)</font>
# * Then, use groupby() in years and use apply function which returns the sorted values with respect to 'score' column? <font color='blue'> (15 points)</font>
# * Display the songs having the first 4 best scores in 2009. Please be sure there is no duplication in the data! <font color='blue'> (10 points)</font>

# %%
newsongs=songs.loc[::,['popularity', 'danceability', 'energy', 'year', 'tempo', 'song']]
newsongs
# Out:
#       popularity  danceability  energy  year     tempo  \
# 0             77         751.0  834.00  2000   95053.0
# 1             79         434.0  897.00  1999  148726.0
# 2             66         529.0  496.00  1999  136859.0
# 3             78         551.0  913.00  2000  119992.0
# 4             65         614.0  928.00  2000  172656.0
# ...          ...           ...     ...   ...       ...
# 1995          79         842.0  734.00  2019  137958.0
# 1996          78         552.0  702.00  2019  169994.0
# 1997          69         847.0  678.00  2019   97984.0
# 1998          75         741.0    0.52  2019  102998.0
# 1999          85         695.0  762.00  2019  120042.0
#
#                                         song
# 0                     Oops!...I Did It Again
# 1                       All The Small Things
# 2                                    Breathe
# 3                               It's My Life
# 4                                Bye Bye Bye
# ...                                      ...
# 1995                                  Sucker
# 1996                            Cruel Summer
# 1997                              The Git Up
# 1998  Dancing With A Stranger (with Normani)
# 1999                                 Circles
#
# [2000 rows x 6 columns]

# %%
newsongs['pop%']=new_songs.groupby('song')['popularity'].transform(lambda x: x*0.01)

# %%
newsongs
# Out:
#       popularity  danceability  energy  year     tempo  \
# 0             77         751.0  834.00  2000   95053.0
# 1             79         434.0  897.00  1999  148726.0
# 2             66         529.0  496.00  1999  136859.0
# 3             78         551.0  913.00  2000  119992.0
# 4             65         614.0  928.00  2000  172656.0
# ...          ...           ...     ...   ...       ...
# 1995          79         842.0  734.00  2019  137958.0
# 1996          78         552.0  702.00  2019  169994.0
# 1997          69         847.0  678.00  2019   97984.0
# 1998          75         741.0    0.52  2019  102998.0
# 1999          85         695.0  762.00  2019  120042.0
#
#                                         song  pop%
# 0                     Oops!...I Did It Again  0.77
# 1                       All The Small Things  0.79
# 2                                    Breathe  0.66
# 3                               It's My Life  0.78
# 4                                Bye Bye Bye  0.65
# ...                                      ...   ...
# 1995                                  Sucker  0.79
# 1996                            Cruel Summer  0.78
# 1997                              The Git Up  0.69
# 1998  Dancing With A Stranger (with Normani)  0.75
# 1999                                 Circles  0.85
#
# [2000 rows x 7 columns]

# %%
song_rearranged=newsongs.set_index('year')

# %%
song_rearranged
# Out:
#       popularity  danceability  energy     tempo  \
# year
# 2000          77         751.0  834.00   95053.0
# 1999          79         434.0  897.00  148726.0
# 1999          66         529.0  496.00  136859.0
# 2000          78         551.0  913.00  119992.0
# 2000          65         614.0  928.00  172656.0
# ...          ...           ...     ...       ...
# 2019          79         842.0  734.00  137958.0
# 2019          78         552.0  702.00  169994.0
# 2019          69         847.0  678.00   97984.0
# 2019          75         741.0    0.52  102998.0
# 2019          85         695.0  762.00  120042.0
#
#                                         song  pop%
# year
# 2000                  Oops!...I Did It Again  0.77
# 1999                    All The Small Things  0.79
# 1999                                 Breathe  0.66
# 2000                            It's My Life  0.78
# 2000                             Bye Bye Bye  0.65
# ...                                      ...   ...
# 2019                                  Sucker  0.79
# 2019                            Cruel Summer  0.78
# 2019                              The Git Up  0.69
# 2019  Dancing With A Stranger (with Normani)  0.75
# 2019                                 Circles  0.85
#
# [2000 rows x 6 columns]

# %%
song_rearranged['score']=song_rearranged[['popularity', 'danceability', 'energy']].mean(axis=1)

# %%
song_rearranged
# Out:
#       popularity  danceability  energy     tempo  \
# year
# 2000          77         751.0  834.00   95053.0
# 1999          79         434.0  897.00  148726.0
# 1999          66         529.0  496.00  136859.0
# 2000          78         551.0  913.00  119992.0
# 2000          65         614.0  928.00  172656.0
# ...          ...           ...     ...       ...
# 2019          79         842.0  734.00  137958.0
# 2019          78         552.0  702.00  169994.0
# 2019          69         847.0  678.00   97984.0
# 2019          75         741.0    0.52  102998.0
# 2019          85         695.0  762.00  120042.0
#
#                                         song  pop%       score
# year
# 2000                  Oops!...I Did It Again  0.77  554.000000
# 1999                    All The Small Things  0.79  470.000000
# 1999                                 Breathe  0.66  363.666667
# 2000                            It's My Life  0.78  514.000000
# 2000                             Bye Bye Bye  0.65  535.666667
# ...                                      ...   ...         ...
# 2019                                  Sucker  0.79  551.666667
# 2019                            Cruel Summer  0.78  444.000000
# 2019                              The Git Up  0.69  531.333333
# 2019  Dancing With A Stranger (with Normani)  0.75  272.173333
# 2019                                 Circles  0.85  514.000000
#
# [2000 rows x 7 columns]

# %%
song_rearranged.groupby(['year']).apply(lambda x: x.sort_values('score', ascending=True))
# Out:
#        popularity  danceability  energy     tempo  \
# year
# 2000           50          0.61    0.82  127993.0
# 2000           60          0.63    0.95  143866.0
# 2000           75          0.85    0.70  101875.0
# 2000           54        518.00    0.83   95468.0
# 2000           68        607.00    0.82  126988.0
# ...           ...           ...     ...       ...
# 2014            0        832.00  815.00  119995.0
# 2014           69        912.00  716.00   94981.0
# 2014            0        789.00  915.00  127955.0
# 2014           59        719.00  935.00  120022.0
# False        2017         74.00  704.00     926.0
#
#                                      song   pop%       score
# year
# 2000                       Another Chance   0.50   17.143333
# 2000          She Bangs - English Version   0.60   20.526667
# 2000                          Ride Wit Me   0.75   25.516667
# 2000                                 Bent   0.54  190.943333
# 2000                           Breathless   0.68  225.273333
# ...                                   ...    ...         ...
# 2014   Look Right Through - MK Vocal Edit   0.00  549.000000
# 2014                                Fancy   0.69  565.666667
# 2014               #SELFIE - Original Mix   0.00  568.000000
# 2014                        Love Runs Out   0.59  571.000000
# False                     Finesse - Remix  20.17  931.666667
#
# [2000 rows x 7 columns]

# %%
s=song_rearranged.groupby(['year']).apply(lambda x: x.sort_values('score'))

# %%
s.drop_duplicates
first_four=s.loc[['2009']].iloc[80:84]
first_four.sort_values('score', ascending=False)
# Out:
#       popularity  danceability  energy     tempo  \
# year
# 2009          63         924.0   853.0  114003.0
# 2009          47         804.0   976.0  125997.0
# 2009          68         867.0   857.0  130048.0
# 2009          71         753.0   931.0  113029.0
#
#                                                  song  pop%       score
# year
# 2009                                      We Made You  0.63  613.333333
# 2009                                        Riverside  0.47  609.000000
# 2009                                    Boom Boom Pow  0.68  597.333333
# 2009  4 Minutes (feat. Justin Timberlake & Timbaland)  0.71  585.000000
